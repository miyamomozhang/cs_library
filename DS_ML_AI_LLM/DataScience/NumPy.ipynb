# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np

# %%
a = np.arange(6)
a
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
a2 = a[np.newaxis, :5]
a2.shape
a2
# Out:
# array([[0, 1, 2, 3, 4]])

# %% [markdown]
# # Linear algebra on n-dimensional arrays
#
# n 维数组线性变换: ndarray
# - 理解 一维，二维，n维数组在numpy中的不同；
# - 学会使用线性代数相关知识对n维数组操作而不是使用for-loops;
# - 理解n维数组的轴和形状变换。

# %% [markdown]
# ## 图像
#
# RGB三原色 3维矩阵 three 2D arrays，
# 比如：
# img.shape # (768, 1024, 3)
# img.ndim  # 3
# 我们有三个矩阵，每一个矩阵是768x1024
#  it indicates that we have an array of 3 matrices, each having shape 768x1024.

# %% [markdown]
# imread

# %%
from scipy import misc
img = misc.face()
img.shape # (768, 1024, 3)

# # 每一个元素都在0~255之间
# img[:, :, 0] # 取red
# img[:, :, 1] # 取green
# img[:, :, 2] # 取blue

# img.ndim  # 3
# img
img.dtype   # dtype('uint8') 8位无符号整数

img_array = img / 255
img_array.dtype     # dtype('float64')
# img_array.max(), img_array.min() #(1.0, 0.0)
red_array = img_array[:, :, 0]
green_array = img_array[:, :, 1]
blue_array = img_array[:, :, 2]
# Out:
# /var/folders/y5/gdn6q6nn5v1f5186jcltr4t40000gn/T/ipykernel_2950/1481510837.py:2: DeprecationWarning: scipy.misc.face has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.face instead.
#   img = misc.face()
# (768, 1024, 3)
# dtype('uint8')
# (1.0, 0.0)
# dtype('float64')

# %%
import matplotlib.pyplot as plt

plt.imshow(img)
plt.show()

plt.imshow(img_array)
plt.show()

# %% [markdown]
# ## 线性代数模块 numpy.linalg
#
# linear algebra module
#
# 注意：numpy.linalg的大部分功能在scipy.linalg中也实现了，实际应用中鼓励使用scipy.linalg这个模块
#
# 但是：scipy的有些模块，比如svd(奇异值分解)只支持2D arrays（矩阵），不支持3维的。

# %%
from numpy import linalg

# %%
img_gray = img_array @ [0.2126, 0.7152, 0.0722]
